# %% [markdown]
# # SAAF Notebook
#
# This Jupyeter Notebook provides an interactive platform for FaaS development.

# %%
# Imports and setup for the notebook.
sys.path.append(os.path.realpath('..'))
import os
import sys
import enum
from platforms.jupyter.interactive_helpers import *
from enum import Enum
class Platform(Enum):
    AWS = 1
    GCF = 2
    IBM = 3
    AZURE = 4

config = {
    "functionName": "SAAFNotebook",
    "lambdaRoleARN": "arn:aws:iam::616835888336:role/service-role/simple_microservice_role"
}

# %% [markdown]
# # Your Function
#
# Write your function below and run the cell to automatically deploy to the specified platforms in interactive_preprocesso.

# %%
interactive_preprocess(platforms=[Platform.AWS, Platform.IBM, Platform.GCF, Platform.AZURE], memory=512, config=config)

import json
import logging
from Inspector import *
import time

#
# Define your FaaS Function here. 
# Each platform handler will call and pass parameters to this function.
# 
# @param request A JSON object provided by the platform handler.
# @param context A platform specific object used to communicate with the cloud platform.
# @returns A JSON object to use as a response. 
#
def yourFunction(request, context):
    # Import the module and collect data
    inspector = Inspector()
    inspector.inspectAll()

    # Add custom message and finish the function
    if ('name' in request):
        inspector.addAttribute("message", "Mello " + str(request['name']) + "!")
    else:
        inspector.addAttribute("message", "Hello World!")
    
    inspector.inspectAllDeltas()
    return inspector.finish()
# Out:
# Starting ../deploy/publish.sh for AWS...
#
# Deploying SAAFNotebook...
#
#
# ----- Deploying onto AWS Lambda -----
#
#   adding: handler.py (deflated 50%)
#   adding: Inspector.py (deflated 76%)
#   adding: Inspector.pyc (deflated 64%)
#   adding: interactive.ipynb (deflated 69%)
#   adding: lambda_function.py (deflated 36%)
#   adding: __pycache__/ (stored 0%)
#   adding: __pycache__/Inspector.cpython-37.pyc (deflated 54%)
#   adding: __pycache__/Inspector.cpython-38.pyc (deflated 53%)
# {
#     "FunctionName": "SAAFNotebook",
#     "FunctionArn": "arn:aws:lambda:us-east-1:616835888336:function:SAAFNotebook",
#     "Runtime": "python3.7",
#     "Role": "arn:aws:iam::616835888336:role/service-role/simple_microservice_role",
#     "Handler": "lambda_function.lambda_handler",
#     "CodeSize": 17684,
#     "Description": "",
#     "Timeout": 900,
#     "MemorySize": 512,
#     "LastModified": "2021-04-17T22:27:23.242+0000",
#     "CodeSha256": "Y8PCdEPsoartOEubchnxrHEiA/2yC9ac5cv7TEtf9i8=",
#     "Version": "$LATEST",
#     "VpcConfig": {
#         "SubnetIds": [],
#         "SecurityGroupIds": [],
#         "VpcId": ""
#     },
#     "Environment": {
#         "Variables": {
#             "EXAMPLEVAR1": "VAL1",
#             "EXAMPLEVAR2": "VAL2"
#         }
#     },
#     "TracingConfig": {
#         "Mode": "PassThrough"
#     },
#     "RevisionId": "06eeb6f5-a671-48e4-9665-67bfe9cf15f1",
#     "State": "Active",
#     "LastUpdateStatus": "Successful",
#     "PackageType": "Zip"
# }
# {
#     "FunctionName": "SAAFNotebook",
#     "FunctionArn": "arn:aws:lambda:us-east-1:616835888336:function:SAAFNotebook",
#     "Runtime": "python3.7",
#     "Role": "arn:aws:iam::616835888336:role/service-role/simple_microservice_role",
#     "Handler": "lambda_function.lambda_handler",
#     "CodeSize": 17684,
#     "Description": "",
#     "Timeout": 900,
#     "MemorySize": 512,
#     "LastModified": "2021-04-17T22:27:23.967+0000",
#     "CodeSha256": "Y8PCdEPsoartOEubchnxrHEiA/2yC9ac5cv7TEtf9i8=",
#     "Version": "$LATEST",
#     "VpcConfig": {
#         "SubnetIds": [],
#         "SecurityGroupIds": [],
#         "VpcId": ""
#     },
#     "Environment": {
#         "Variables": {
#             "EXAMPLEVAR1": "VAL1",
#             "EXAMPLEVAR2": "VAL2"
#         }
#     },
#     "TracingConfig": {
#         "Mode": "PassThrough"
#     },
#     "RevisionId": "a8f11e24-f122-482b-8055-5c23618c5f86",
#     "State": "Active",
#     "LastUpdateStatus": "Successful",
#     "PackageType": "Zip"
# }
#
# Testing function on AWS Lambda...
# {"version": 0.5, "lang": "python", "startTime": 1618698445034, "uuid": "d60bcf0d-fd54-4d91-a189-d3451b774d3f", "newcontainer": 1, "vmuptime": 1618697349, "platform": "AWS Lambda", "containerID": "2021/04/17/[$LATEST]d268dc20f8574716a5ee59b82d9f859d", "functionName": "SAAFNotebook", "functionMemory": "512", "functionRegion": "us-east-1", "vmID": "", "linuxVersion": "Linux 169.254.113.253 4.14.225-175.364.amzn2.x86_64 #1 SMP Mon Mar 22 22:06:01 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux", "totalMemory": 642644, "freeMemory": 529928, "pageFaults": 82267, "cpuType": "Intel(R) Xeon(R) Processor @ 2.50GHz", "cpuModel": "63", "cpuUsr": 33, "cpuNice": 0, "cpuKrn": 84, "cpuIdle": 218904, "cpuIowait": 8, "cpuIrq": 0, "cpuSoftIrq": 1, "vmcpusteal": 49, "contextSwitches": 19898, "frameworkRuntime": 98, "message": "Hello World!", "userRuntime": 0, "cpuUsrDelta": 0, "cpuNiceDelta": 0, "cpuKrnDelta": 1, "cpuIdleDelta": 6, "cpuIowaitDelta": 0, "cpuIrqDelta": 0, "cpuSoftIrqDelta": 0, "vmcpustealDelta": 0, "contextSwitchesDelta": 51, "pageFaultsDelta": 3878, "frameworkRuntimeDeltas": 36, "runtime": 134, "endTime": 1618698445168}{
#     "StatusCode": 200,
#     "ExecutedVersion": "$LATEST"
# }
#
# Deploy Complete!
# Starting ../deploy/publish.sh for IBM..
#
# Deploying SAAFNotebook...
#
#
# ----- Deploying onto IBM Cloud Functions -----
#
#   adding: handler.py (deflated 50%)
#   adding: Inspector.py (deflated 76%)
#   adding: Inspector.pyc (deflated 64%)
#   adding: interactive.ipynb (deflated 69%)
#   adding: __main__.py (deflated 34%)
#   adding: __pycache__/ (stored 0%)
#   adding: __pycache__/Inspector.cpython-37.pyc (deflated 54%)
#   adding: __pycache__/Inspector.cpython-38.pyc (deflated 53%)
#   adding: README.md (deflated 7%)
# ok: updated action SAAFNotebook
#
# Testing function on IBM Cloud Functions...
#
# Deploy Complete!
# Starting ../deploy/publish.sh for GCF..
#
# Deploying SAAFNotebook...
#
#
# ----- Deploying onto Google Cloud Functions -----
#
# availableMemoryMb: 512
# buildId: 5b8f9fbb-cf82-4a52-ab70-daa596a93883
# entryPoint: hello_world
# httpsTrigger:
#   securityLevel: SECURE_OPTIONAL
#   url: https://us-central1-api-project-692688302945.cloudfunctions.net/SAAFNotebook
# ingressSettings: ALLOW_ALL
# labels:
#   deployment-tool: cli-gcloud
# name: projects/api-project-692688302945/locations/us-central1/functions/SAAFNotebook
# runtime: python37
# serviceAccountEmail: api-project-692688302945@appspot.gserviceaccount.com
# sourceUploadUrl: https://storage.googleapis.com/gcf-upload-us-central1-a73fca8f-56d8-4fe9-a58b-315a5bc329c6/eb7eade1-4d15-4891-aa05-e48ae75bd41d.zip?GoogleAccessId=service-692688302945@gcf-admin-robot.iam.gserviceaccount.com&Expires=1618700247&Signature=JDewsfa%2Ft0i6IV%2FVyXrm91A3CKmL1%2FrMx9jkSeDvO53%2BGAobvJYniFYcqafkK%2BJZu6ALgQXCHq7HnL%2BN4joF%2FpGKN6Y%2FU%2Fxy91e%2Frr%2FDYbvGTKKfhdvT0MuBAJKIyS0Vp6JQKlF2dlx7e3rK5wNUB3Ve82zUQRa9H1%2BExjzp2TEWTUPq8u95ACfIeBfi0pKFDNbGIras3%2FFIroCl6uZPk69npMbu3%2F8bVQJrA2q5tPv1WUbZ%2B7E1SbVrNwL1V3HJoWF175PkRQVMbD5yZ2NxGd0ZX7VjMPcpBeRuyQBsdeI1RgS0dpQ9cVJPyyDoqUWwrCm6KV4ipE%2FPcckGRUo4tw%3D%3D
# status: ACTIVE
# timeout: 540s
# updateTime: '2021-04-17T22:28:01.697Z'
# versionId: '2'
#
# Testing function on Google Cloud Functions... This may fail. It may take a moment for functions to start working after they are deployed.
# executionId: fjnl32f706q4
# result: '{"version": 0.5, "lang": "python", "startTime": 1618698482718, "uuid": "ee82f3b5-6a4c-43a2-9ef4-5121de93ea1e",
#   "newcontainer": 1, "vmuptime": 1618698473, "platform": "Google Cloud Functions",
#   "functionName": "SAAFNotebook", "functionMemory": "512", "functionRegion": "us-central1",
#   "linuxVersion": "Linux localhost 4.4.0 #1 SMP Sun Jan 10 15:06:54 PST 2016 x86_64
#   x86_64 x86_64 GNU/Linux", "totalMemory": 2097152, "freeMemory": 2049280, "SAAFMemoryError":
#   "/proc/vmstat does not exist!", "cpuType": "unknown", "cpuModel": "79", "cpuUsr":
#   0, "cpuNice": 0, "cpuKrn": 0, "cpuIdle": 0, "cpuIowait": 0, "cpuIrq": 0, "cpuSoftIrq":
#   0, "vmcpusteal": 0, "contextSwitches": 0, "frameworkRuntime": 647, "message": "Hello
#   World!", "userRuntime": 0, "cpuUsrDelta": 0, "cpuNiceDelta": 0, "cpuKrnDelta": 0,
#   "cpuIdleDelta": 0, "cpuIowaitDelta": 0, "cpuIrqDelta": 0, "cpuSoftIrqDelta": 0,
#   "vmcpustealDelta": 0, "contextSwitchesDelta": 0, "SAAFMemoryDeltaError": "/proc/vmstat
#   does not exist!", "frameworkRuntimeDeltas": 293, "runtime": 940, "endTime": 1618698483658}'
#
# Deploy Complete!
# Starting ../deploy/publish.sh for Azure..
#
# Deploying SAAFNotebook...
#
#
# ----- Deploying onto Azure Functions -----
#
# Creating resources...
# Deploying function... This may fail if the function app is brand new. In that event, please run this script again.
#
# Testing function on Azure Functions...
#
#
# Deploy Complete!

# %% [markdown]
# # Test Locally
#
# Customize the payload object and test your function locally.
# SAAF only works on Linux so test on the cloud if using macOS or Windows.

# %%
# Test your function locally:
payload = {
    "name": "Steve"
}

yourFunction(payload, None)
# Out:
# {'version': 0.5,
#  'lang': 'python',
#  'startTime': 1618698232810,
#  'uuid': '8bcc79c8-165e-4a33-be86-37b7eb011e7e',
#  'newcontainer': 0,
#  'vmuptime': 1618626633,
#  'platform': 'Unknown Platform',
#  'linuxVersion': 'Linux ubuntuserver 5.4.0-71-generic #79-Ubuntu SMP Wed Mar 24 10:56:57 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux',
#  'totalMemory': 32882248,
#  'freeMemory': 26168912,
#  'pageFaults': 151466311,
#  'cpuType': 'Intel(R) Core(TM) i9-9900K CPU @ 3.60GHz',
#  'cpuModel': '158',
#  'cpuUsr': 148654,
#  'cpuNice': 434,
#  'cpuKrn': 217303,
#  'cpuIdle': 71212137,
#  'cpuIowait': 515,
#  'cpuIrq': 0,
#  'cpuSoftIrq': 3108,
#  'vmcpusteal': 0,
#  'contextSwitches': 109329414,
#  'frameworkRuntime': 33,
#  'message': 'Mello Steve!',
#  'userRuntime': 0,
#  'cpuUsrDelta': 0,
#  'cpuNiceDelta': 0,
#  'cpuKrnDelta': 1,
#  'cpuIdleDelta': 9,
#  'cpuIowaitDelta': 0,
#  'cpuIrqDelta': 0,
#  'cpuSoftIrqDelta': 0,
#  'vmcpustealDelta': 0,
#  'contextSwitchesDelta': 55,
#  'pageFaultsDelta': 3914,
#  'frameworkRuntimeDeltas': 10,
#  'runtime': 43,
#  'endTime': 1618698232853}

# %% [markdown]
# # Test on the Cloud
#
# Execute your function on AWS Lambda. Output will be formatted into Pandas dataframe.

# %%
# Test your function on the cloud:
payload = {
    "name": "Steve"
}

test_on_cloud(platforms=[Platform.AWS, Platform.IBM, Platform.GCF, Platform.AZURE], payload=payload, config=config)
# Out:
# ----- Testing on AWS Lambda -----
#
#
# Testing function on AWS Lambda...
# {"version": 0.5, "lang": "python", "startTime": 1618698408308, "uuid": "ca1b4124-cbbe-42cf-adc9-ca8d25409d2d", "newcontainer": 0, "vmuptime": 1618696758, "platform": "AWS Lambda", "containerID": "2021/04/17/[$LATEST]c38c2ab551424c4588cfe1dc50b9618d", "functionName": "SAAFNotebook", "functionMemory": "512", "functionRegion": "us-east-1", "vmID": "", "linuxVersion": "Linux 169.254.1.165 4.14.225-175.364.amzn2.x86_64 #1 SMP Mon Mar 22 22:06:01 UTC 2021 x86_64 x86_64 x86_64 GNU/Linux", "totalMemory": 642644, "freeMemory": 524784, "pageFaults": 101182, "cpuType": "Intel(R) Xeon(R) Processor @ 2.50GHz", "cpuModel": "63", "cpuUsr": 50, "cpuNice": 0, "cpuKrn": 96, "cpuIdle": 329702, "cpuIowait": 6, "cpuIrq": 0, "cpuSoftIrq": 0, "vmcpusteal": 22, "contextSwitches": 30436, "frameworkRuntime": 72, "message": "Hello World!", "userRuntime": 0, "cpuUsrDelta": 0, "cpuNiceDelta": 0, "cpuKrnDelta": 0, "cpuIdleDelta": 7, "cpuIowaitDelta": 0, "cpuIrqDelta": 0, "cpuSoftIrqDelta": 0, "vmcpustealDelta": 0, "contextSwitchesDelta": 49, "pageFaultsDelta": 3882, "frameworkRuntimeDeltas": 38, "runtime": 110, "endTime": 1618698408418}{
#     "StatusCode": 200,
#     "ExecutedVersion": "$LATEST"
# }
#
#
# ----- Testing on IBM Cloud Functions -----
#
#
# Testing function on IBM Cloud Functions...
#
#
# ----- Testing on Google Cloud Functions -----
#
#
# Testing function on Google Cloud Functions... This may fail. It may take a moment for functions to start working after they are deployed.
# executionId: u76vwgpbj4fb
# result: '{"version": 0.5, "lang": "python", "startTime": 1618698409449, "uuid": "47dfa120-5ad6-44c7-a4bd-91e61b3d602a",
#   "newcontainer": 0, "vmuptime": 1618698228, "platform": "Google Cloud Functions",
#   "functionName": "SAAFNotebook", "functionMemory": "512", "functionRegion": "us-central1",
#   "linuxVersion": "Linux localhost 4.4.0 #1 SMP Sun Jan 10 15:06:54 PST 2016 x86_64
#   x86_64 x86_64 GNU/Linux", "totalMemory": 2097152, "freeMemory": 2050276, "SAAFMemoryError":
#   "/proc/vmstat does not exist!", "cpuType": "unknown", "cpuModel": "85", "cpuUsr":
#   0, "cpuNice": 0, "cpuKrn": 0, "cpuIdle": 0, "cpuIowait": 0, "cpuIrq": 0, "cpuSoftIrq":
#   0, "vmcpusteal": 0, "contextSwitches": 0, "frameworkRuntime": 816, "message": "Hello
#   World!", "userRuntime": 0, "cpuUsrDelta": 0, "cpuNiceDelta": 0, "cpuKrnDelta": 0,
#   "cpuIdleDelta": 0, "cpuIowaitDelta": 0, "cpuIrqDelta": 0, "cpuSoftIrqDelta": 0,
#   "vmcpustealDelta": 0, "contextSwitchesDelta": 0, "SAAFMemoryDeltaError": "/proc/vmstat
#   does not exist!", "frameworkRuntimeDeltas": 304, "runtime": 1120, "endTime": 1618698410569}'
#
#
# ----- Testing on Azure Functions -----
#
#
# Testing function on Azure Functions...
