# %%
import SAAF
import FaaSET
import FaaSETUI
# Out:
# ------------------------------------------------------
#              Welcome to FaaSET v3.0!
# ------------------------------------------------------
# Available platforms:  demo. ibm_code_engine. aws_docker_arm. aws_docker_debian. azure. aws_function_url. aws_docker. google. oracle. google_gen2. openfaas_eks. digital_ocean. ibm. local. aws_api_gateway. aws_boto3. ibm_docker. aws. openfaas.
# ------------------------------------------------------
# Loaded functions:

# %%
function_config = {
    "role": "arn:aws:iam::616835888336:role/service-role/simple_microservice_role",
    "memory": 256,
    "profile": "personal"
}

# %%
@FaaSET.cloud_function(platform="aws", config=function_config)
def hello_world(request, context): 
    from SAAF import Inspector
    inspector = Inspector() 
    inspector.inspectAll()
    inspector.addAttribute("message", "Hello from the cloud " + str(request["name"]) + "!")
    inspector.inspectAllDeltas() 
    return inspector.finish()

hello_world({"name": "Bob"})
# Out:
# An error occurred (ResourceConflictException) when calling the CreateFunctionUrlConfig operation: Failed to create function url config for [functionArn = arn:aws:lambda:us-east-1:616835888336:function:hello_world]. Error message:  FunctionUrlConfig exists for this Lambda function
# Build: Purging previous build...
# Build: Copying files...
# Build: Cleaning up...
# Build: Creating Zip...
#   adding: cli_run.py (deflated 28%)
#   adding: default_config.json (deflated 42%)
#   adding: error.log (stored 0%)
#   adding: handler.py (deflated 35%)
#   adding: lambda_function.py (deflated 48%)
#   adding: SAAF.py (deflated 76%)
# Publish: Loading config...
# Publish: Deploying function...
# Publish: Updating function configuration...
# {
#     "FunctionName": "hello_world",
#     "FunctionArn": "arn:aws:lambda:us-east-1:616835888336:function:hello_world",
#     "Runtime": "python3.8",
#     "Role": "arn:aws:iam::616835888336:role/service-role/simple_microservice_role",
#     "Handler": "lambda_function.lambda_handler",
#     "CodeSize": 6071,
#     "Description": "",
#     "Timeout": 900,
#     "MemorySize": 256,
#     "LastModified": "2024-05-03T07:18:56.000+0000",
#     "CodeSha256": "ZCxdqF+fRVvcZoH/vD2RggxaJAiypexyWZ+aoY7v0Bk=",
#     "Version": "$LATEST",
#     "VpcConfig": {
#         "SubnetIds": [],
#         "SecurityGroupIds": [],
#         "VpcId": ""
#     },
#     "TracingConfig": {
#         "Mode": "PassThrough"
#     },
#     "RevisionId": "4ba83dcb-cd14-4b40-832e-52467e9eb323",
#     "State": "Active",
#     "LastUpdateStatus": "InProgress",
#     "LastUpdateStatusReason": "The function is being created.",
#     "LastUpdateStatusReasonCode": "Creating",
#     "PackageType": "Zip",
#     "Architectures": [
#         "x86_64"
#     ],
#     "EphemeralStorage": {
#         "Size": 512
#     }
# }
# Publish: Updating function code...
# {
#     "FunctionName": "hello_world",
#     "FunctionArn": "arn:aws:lambda:us-east-1:616835888336:function:hello_world",
#     "Runtime": "python3.8",
#     "Role": "arn:aws:iam::616835888336:role/service-role/simple_microservice_role",
#     "Handler": "lambda_function.lambda_handler",
#     "CodeSize": 6072,
#     "Description": "",
#     "Timeout": 900,
#     "MemorySize": 256,
#     "LastModified": "2024-05-03T07:18:58.000+0000",
#     "CodeSha256": "OI+BF1lTK5ZBZa27tYMx110B4/QvLLswvwEJ7+d0j1I=",
#     "Version": "$LATEST",
#     "VpcConfig": {
#         "SubnetIds": [],
#         "SecurityGroupIds": [],
#         "VpcId": ""
#     },
#     "TracingConfig": {
#         "Mode": "PassThrough"
#     },
#     "RevisionId": "908f6e2a-3efc-4d32-98ec-037a221c5172",
#     "State": "Active",
#     "LastUpdateStatus": "InProgress",
#     "LastUpdateStatusReason": "The function is being created.",
#     "LastUpdateStatusReasonCode": "Creating",
#     "PackageType": "Zip",
#     "Architectures": [
#         "x86_64"
#     ],
#     "EphemeralStorage": {
#         "Size": 512
#     }
# }
#
# An error occurred (ResourceConflictException) when calling the CreateFunctionUrlConfig operation: Failed to create function url config for [functionArn = arn:aws:lambda:us-east-1:616835888336:function:hello_world]. Error message:  FunctionUrlConfig exists for this Lambda function
# Publish: Function deployed!
# {'version': 0.7,
#  'lang': 'python',
#  'startTime': 1714720747120,
#  'invocations': 1,
#  'initializationTime': 1714720747099,
#  'uuid': '12c906b0-1947-4295-b1cd-df01b041cba4',
#  'newcontainer': 1,
#  'cpuType': 'Intel(R) Xeon(R) Processor @ 2.50GHz',
#  'cpuModel': '63',
#  'architecture': 'x86',
#  'cpuCores': 2,
#  'cpuInfo': [{'processor': '0',
#    'vendor_id': 'GenuineIntel',
#    'cpu_family': '6',
#    'model': '63',
#    'model_name': 'Intel(R) Xeon(R) Processor @ 2.50GHz',
#    'stepping': '2',
#    'microcode': '0x1',
#    'cpu_MHz': '2499.988',
#    'cache_size': '36608 KB',
#    'physical_id': '0',
#    'siblings': '2',
#    'core_id': '0',
#    'cpu_cores': '2',
#    'apicid': '0',
#    'initial_apicid': '0',
#    'fpu': 'yes',
#    'fpu_exception': 'yes',
#    'cpuid_level': '22',
#    'wp': 'yes',
#    'flags': ['fpu',
#     'vme',
#     'de',
#     'pse',
#     'tsc',
#     'msr',
#     'pae',
#     'mce',
#     'cx8',
#     'apic',
#     'sep',
#     'mtrr',
#     'pge',
#     'mca',
#     'cmov',
#     'pat',
#     'pse36',
#     'clflush',
#     'mmx',
#     'fxsr',
#     'sse',
#     'sse2',
#     'ht',
#     'syscall',
#     'nx',
#     'rdtscp',
#     'lm',
#     'constant_tsc',
#     'rep_good',
#     'nopl',
#     'xtopology',
#     'nonstop_tsc',
#     'cpuid',
#     'tsc_known_freq',
#     'pni',
#     'pclmulqdq',
#     'ssse3',
#     'fma',
#     'cx16',
#     'pcid',
#     'sse4_1',
#     'sse4_2',
#     'x2apic',
#     'movbe',
#     'popcnt',
#     'tsc_deadline_timer',
#     'aes',
#     'xsave',
#     'avx',
#     'f16c',
#     'rdrand',
#     'hypervisor',
#     'lahf_lm',
#     'abm',
#     'cpuid_fault',
#     'invpcid_single',
#     'ssbd',
#     'ibrs',
#     'ibpb',
#     'stibp',
#     'ibrs_enhanced',
#     'fsgsbase',
#     'tsc_adjust',
#     'bmi1',
#     'avx2',
#     'smep',
#     'bmi2',
#     'erms',
#     'invpcid',
#     'smap',
#     'xsaveopt',
#     'arat',
#     'md_clear',
#     'arch_capabilities'],
#    'bugs': ['spectre_v1',
#     'spectre_v2',
#     'spec_store_bypass',
#     'swapgs',
#     'taa',
#     'mmio_stale_data'],
#    'bogomips': '4999.97',
#    'clflush_size': '64',
#    'cache_alignment': '64',
#    'address_sizes': '46 bits physical, 48 bits virtual'},
#   {'processor': '1',
#    'vendor_id': 'GenuineIntel',
#    'cpu_family': '6',
#    'model': '63',
#    'model_name': 'Intel(R) Xeon(R) Processor @ 2.50GHz',
#    'stepping': '2',
#    'microcode': '0x1',
#    'cpu_MHz': '2499.988',
#    'cache_size': '36608 KB',
#    'physical_id': '0',
#    'siblings': '2',
#    'core_id': '1',
#    'cpu_cores': '2',
#    'apicid': '1',
#    'initial_apicid': '1',
#    'fpu': 'yes',
#    'fpu_exception': 'yes',
#    'cpuid_level': '22',
#    'wp': 'yes',
#    'flags': ['fpu',
#     'vme',
#     'de',
#     'pse',
#     'tsc',
#     'msr',
#     'pae',
#     'mce',
#     'cx8',
#     'apic',
#     'sep',
#     'mtrr',
#     'pge',
#     'mca',
#     'cmov',
#     'pat',
#     'pse36',
#     'clflush',
#     'mmx',
#     'fxsr',
#     'sse',
#     'sse2',
#     'ht',
#     'syscall',
#     'nx',
#     'rdtscp',
#     'lm',
#     'constant_tsc',
#     'rep_good',
#     'nopl',
#     'xtopology',
#     'nonstop_tsc',
#     'cpuid',
#     'tsc_known_freq',
#     'pni',
#     'pclmulqdq',
#     'ssse3',
#     'fma',
#     'cx16',
#     'pcid',
#     'sse4_1',
#     'sse4_2',
#     'x2apic',
#     'movbe',
#     'popcnt',
#     'tsc_deadline_timer',
#     'aes',
#     'xsave',
#     'avx',
#     'f16c',
#     'rdrand',
#     'hypervisor',
#     'lahf_lm',
#     'abm',
#     'cpuid_fault',
#     'invpcid_single',
#     'ssbd',
#     'ibrs',
#     'ibpb',
#     'stibp',
#     'ibrs_enhanced',
#     'fsgsbase',
#     'tsc_adjust',
#     'bmi1',
#     'avx2',
#     'smep',
#     'bmi2',
#     'erms',
#     'invpcid',
#     'smap',
#     'xsaveopt',
#     'arat',
#     'md_clear',
#     'arch_capabilities'],
#    'bugs': ['spectre_v1',
#     'spectre_v2',
#     'spec_store_bypass',
#     'swapgs',
#     'taa',
#     'mmio_stale_data'],
#    'bogomips': '4999.97',
#    'clflush_size': '64',
#    'cache_alignment': '64',
#    'address_sizes': '46 bits physical, 48 bits virtual'}],
#  'platform': 'AWS Lambda',
#  'containerID': '2024/05/03/[$LATEST]79557ffaff2a4b86924ea03012b89137',
#  'functionName': 'hello_world',
#  'functionMemory': '256',
#  'functionRegion': 'us-east-1',
#  'vmID': '',
#  'linuxVersion': 'Linux 169.254.97.229 5.10.214-222.855.amzn2.x86_64 #1 SMP Thu Apr 11 21:52:20 UTC 2024 x86_64 x86_64 x86_64 GNU/Linux',
#  'totalMemory': 334832,
#  'freeMemory': 221164,
#  'pageFaults': 105332,
#  'cpuUser': 470.0,
#  'cpuNice': 0.0,
#  'cpuKernel': 700.0,
#  'cpuIdle': 578940.0,
#  'cpuIOWait': 20.0,
#  'cpuIrq': 0.0,
#  'cpuSoftIrq': 70.0,
#  'cpuSteal': 80.0,
#  'cpuGuest': 0.0,
#  'cpuGuestNice': 0.0,
#  'bootTime': 1714720456,
#  'frameworkRuntime': 60,
#  'message': 'Hello from the bloud Bob!',
#  'userRuntime': 0,
#  'cpuUserDelta': 0.0,
#  'cpuNiceDelta': 0.0,
#  'cpuKernelDelta': 0.0,
#  'cpuIdleDelta': 0.0,
#  'cpuIOWaitDelta': 0.0,
#  'cpuIrqDelta': 0.0,
#  'cpuSoftIrqDelta': 0.0,
#  'cpuStealDelta': 0.0,
#  'cpuGuestDelta': 0.0,
#  'cpuGuestNiceDelta': 0.0,
#  'pageFaultsDelta': 29,
#  'availableCPUs': 0.143,
#  'SAAFRecommendConfigurationError': 'Unable to recommend a configuration. float division by zero',
#  'frameworkRuntimeDeltas': 0,
#  'runtime': 60,
#  'endTime': 1714720747180,
#  'roundTripTime': 1344.23,
#  'payload': {'name': 'Bob'},
#  'latency': 1284.23}
